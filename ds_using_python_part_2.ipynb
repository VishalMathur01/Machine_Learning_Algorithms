# %%
L= [2,32,25,23,2,5,2]

# %%
L
# Out:
# [2, 32, 25, 23, 2, 5, 2]

# %%
T=(4,3, "helo")

# %%
T
# Out:
# (4, 3, 'helo')

# %%
L = L + ['sup', 'bruh', 'add', 'this']

# %%
L
# Out:
# [2, 32, 25, 23, 2, 5, 2, 'sup', 'bruh', 'add', 'this']

# %%
L.append(8.3)

# %%
L
# Out:
# [2, 32, 25, 23, 2, 5, 2, 'sup', 'bruh', 'add', 'this', 8.3, 8.3]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
L3 = L[1:5]

# %%
L3
# Out:
# [32, 25, 23, 2]

# %%
help(L.append)
# Out:
# Help on built-in function append:
#
# append(object, /) method of builtins.list instance
#     Append object to the end of the list.

# %%
L.clear?

# %%
L.pop?

# %%
L.pop?

# %%
# %who
# Out:
# L	 L3	 T

# %%
L3 = [ x**2 for x in range(10)]

# %%
L3
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
L3 = [ x**4 for x in range (20)]

# %%
L3
# Out:
# [0,
#  1,
#  16,
#  81,
#  256,
#  625,
#  1296,
#  2401,
#  4096,
#  6561,
#  10000,
#  14641,
#  20736,
#  28561,
#  38416,
#  50625,
#  65536,
#  83521,
#  104976,
#  130321]

# %%
L3
# Out:
# [0,
#  1,
#  16,
#  81,
#  256,
#  625,
#  1296,
#  2401,
#  4096,
#  6561,
#  10000,
#  14641,
#  20736,
#  28561,
#  38416,
#  50625,
#  65536,
#  83521,
#  104976,
#  130321]

# %%
L3 = [ x**4 for x in range (3)]

# %%
L3
# Out:
# [0, 1, 16]

# %%
S3 = { x**5 for x in range (2, 10, 3)}

# %%
S3
# Out:
# {32, 3125, 32768}

# %%
def gerData():
    D = {}
    while True:
        id = input("Enter the student id: ")
        marks = input("Enter the marks by means of comma separated values: ")
        extra = input("Enter yes/no for adding more students: ")
        if id in D:
            print (id , "is already inserted")
        else:
            D[id] = marks.split(",")
        if extra.lower() == 'no':
            return D

# %%
sudent_data= gerData()
# Out:
# Enter the student id: 23
# Enter the marks by means of comma separated values: 23,43,23
# Enter yes/no for adding more students: no

# %%
sudent_data
# Out:
# {'23': ['23', '43', '23']}

# %%
del sudent_data

# %%
sudent_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4736\3666085144.py in <module>
# ----> 1 sudent_data
#
# NameError: name 'sudent_data' is not defined

# %%
student_data = gerData()
# Out:
# Enter the student id: 5
# Enter the marks by means of comma separated values: 23, 23, 5, 12, 55
# Enter yes/no for adding more students: yes
# Enter the student id: 53
# Enter the marks by means of comma separated values: 23,112,45,234
# Enter yes/no for adding more students: no

# %%
student_data
# Out:
# {'5': ['23', ' 23', ' 5', ' 12', ' 55'], '53': ['23', '112', '45', '234']}

# %%
def avg(D):
    a = {}
    for x in D:
        L = D[x]

# %%
import numpy as np
a = np.array([1, 2, 3, 4, 5])
b = np.array((1, 4, 2, 3, 5), dtype = 'f')
c = np.array((6, 7, 4, 2))

# %%
print(a)
# Out:
# [1 2 3 4 5]

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a.dtype
# Out:
# dtype('int32')

# %%
b.dtype
# Out:
# dtype('float32')

# %%
a = np.array([[1, 2, 3], [4, 5, 6]])

# %%
print (a.ndim)
# Out:
# 2

# %%
print(b.ndim)
# Out:
# 1

# %%
a[0, 1]
# Out:
# 2

# %% [markdown]
# .ndim = defines the number of dimentions in the array
# a[<name of the array inside the muti - dimention array>, <name of the element inside the array called>]

# %%
a = np.array([[1, 2, 3], [4, 5, 6]])

# %%
b = np.array([[2, 5, 6], [2, 4, 3, 2]])
# Out:
# C:\Users\VISHAL\AppData\Local\Temp\ipykernel_7640\2976123703.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   b = np.array([[2, 5, 6], [2, 4, 3, 2]])

# %%
b.ndim
# Out:
# 1

# %% [markdown]
# li
